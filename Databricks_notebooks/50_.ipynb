# %%
print(globals())
# Out:
# {'NotebookImportException': <class 'dbruntime.workspace_import_machinery.NotebookImportException'>, 'display': <bound method Display.display of <dbruntime.display.Display object at 0xff0bd04614f0>>, 'displayHTML': <function displayHTML at 0xff0c0b288180>, 'dbutils': Package 'dbutils'. For more information, type 'dbutils.help()' in a cell., 'udf': <function udf at 0xff0bda5d67a0>, 'getArgument': <bound method WidgetsHandlerImpl.getArgument of Package 'dbutils.widgets'. For more information, type 'dbutils.widgets.help()' in a cell.>, 'sc': <dbruntime.UserNamespaceInitializer.TripWire object at 0xff0bd3b8fa40>, 'sqlContext': <dbruntime.UserNamespaceInitializer.TripWire object at 0xff0bd616e4b0>, 'spark': <pyspark.sql.connect.session.SparkSession object at 0xff0bb6a05b50>, 'table': <bound method SparkSession.table of <pyspark.sql.connect.session.SparkSession object at 0xff0bb6a05b50>>, 'sql': <bound method SparkSession.sql of <pyspark.sql.connect.session.SparkSession object at 0xff0bb6a0
# ...

# %%
for k,v in globals().items():
    print(k)
# Out:
# NotebookImportException
# display
# displayHTML
# dbutils
# udf
# getArgument
# sc
# sqlContext
# spark
# table
# sql
# __name__
# __builtin__
# __builtins__
# _ih
# _oh
# _dh
# In
# Out
# get_ipython
# exit
# quit
# open
# _
# __
# ___
# _i
# _ii
# _iii
# _i1
# _i2
# _i3
# k
# v
# _i4
# _i5
# _i6
# __instrument_exception_types
# __builtins_import_patcher
# __dataframe_expression_watcher
# _i7

# %%
from pyspark.sql import dataframe
for k,v in globals().items():
    if(type(v) == dataframe):
        print(k)
