# %% [markdown]
# https://youtu.be/hdnd56wfQug?si=UCBKTgL2OkaPXwDl

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

data = [
    {"dept_id": 101, "e_id": [10101, 10102, 10103]},
    {"dept_id": 102, "e_id": [10201, 10202]}
]

df = spark.createDataFrame(data=data)
display(df)
df.printSchema()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dept_id</th><th>e_id</th></tr></thead><tbody><tr><td>101</td><td>List(10101, 10102, 10103)</td></tr><tr><td>102</td><td>List(10201, 10202)</td></tr></tbody></table></div>
# root
#  |-- dept_id: long (nullable = true)
#  |-- e_id: array (nullable = true)
#  |    |-- element: long (containsNull = true)

# %%
df1 = df.withColumn("e_id", explode("e_id"))
df1.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dept_id</th><th>e_id</th></tr></thead><tbody><tr><td>101</td><td>10101</td></tr><tr><td>101</td><td>10102</td></tr><tr><td>101</td><td>10103</td></tr><tr><td>102</td><td>10201</td></tr><tr><td>102</td><td>10202</td></tr></tbody></table></div>
