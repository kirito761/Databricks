# %% [markdown]
# https://youtu.be/KkpyT1V-MIs?si=J-fkaChnXBkNSWz-

# %%
# %sql
CREATE or REPLACE TABLE dev.practice.emp_new (employee_id VARCHAR(50));
INSERT INTO dev.practice.emp_new (employee_id) VALUES ('72657'),('1234'),('Tom'),('8792'),('Sam'),('19998'),('Philip');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>7</td><td>7</td></tr></tbody></table></div>

# %%
# %sql
select try_cast(employee_id as int) from dev.practice.emp_new where try_cast(employee_id as int) is not null;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>employee_id</th></tr></thead><tbody><tr><td>72657</td></tr><tr><td>1234</td></tr><tr><td>8792</td></tr><tr><td>19998</td></tr></tbody></table></div>

# %%
df = spark.read.table("dev.practice.emp_new")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>employee_id</th></tr></thead><tbody><tr><td>72657</td></tr><tr><td>1234</td></tr><tr><td>Tom</td></tr><tr><td>8792</td></tr><tr><td>Sam</td></tr><tr><td>19998</td></tr><tr><td>Philip</td></tr></tbody></table></div>

# %%
df.withColumn("id", df["employee_id"].try_cast("int")).filter("id is not null").drop("employee_id").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th></tr></thead><tbody><tr><td>72657</td></tr><tr><td>1234</td></tr><tr><td>8792</td></tr><tr><td>19998</td></tr></tbody></table></div>
