# %% [markdown]
# https://youtu.be/rQ47WjG5CnQ?si=lBu3e2S2fdS9VUfc

# %%
data=[('Joanne',"040-20215632"),('Tom',"044-23651023"),('John',"086-12456782")]
schema=["name","phone"]
df=spark.createDataFrame(data,schema)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>phone</th></tr></thead><tbody><tr><td>Joanne</td><td>040-20215632</td></tr><tr><td>Tom</td><td>044-23651023</td></tr><tr><td>John</td><td>086-12456782</td></tr></tbody></table></div>

# %%
from pyspark.sql import functions as F

# %%
df.withColumn("code",F.split(df.phone,"-")[0]).withColumn("number",F.split(df.phone,"-")[1]).drop("phone").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>code</th><th>number</th></tr></thead><tbody><tr><td>Joanne</td><td>040</td><td>20215632</td></tr><tr><td>Tom</td><td>044</td><td>23651023</td></tr><tr><td>John</td><td>086</td><td>12456782</td></tr></tbody></table></div>
