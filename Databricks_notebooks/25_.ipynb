# %% [markdown]
# https://youtu.be/sYZXnNrq1DA?si=BhsrIMNwh2JEsQBj

# %%
data = [
    (1, "Shivam", "U67536791Y"),
    (2, "Sagar", "7654367862"),
    (3, "Muni", "89765415U7")
]

columns = ["ID", "Student_Name", "MobileNo"]

df = spark.createDataFrame(data, columns)

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ID</th><th>Student_Name</th><th>MobileNo</th></tr></thead><tbody><tr><td>1</td><td>Shivam</td><td>U67536791Y</td></tr><tr><td>2</td><td>Sagar</td><td>7654367862</td></tr><tr><td>3</td><td>Muni</td><td>89765415U7</td></tr></tbody></table></div>

# %%
df.filter(df.MobileNo.rlike("^[0-9]*$")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ID</th><th>Student_Name</th><th>MobileNo</th></tr></thead><tbody><tr><td>2</td><td>Sagar</td><td>7654367862</td></tr></tbody></table></div>
