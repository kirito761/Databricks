# %% [markdown]
# https://youtu.be/geIJ9CbGkSE?si=0dGku8HdFvRRIipy

# %%
df = spark.read.csv('/Workspace/Users/kjawed8@gmail.com/paractice/26.xlsx').limit(10)
df.show()
# Out:
# +--------------------+
# |                 _c0|
# +--------------------+
# |PK\b!LA...|
# |Q��Q\vK��?oH"X�...|
# |�5�"&�K���[��+�...|
# |�׋�(0DP[�l��S�...|
# |?�9L�ҙ�sbgٮ|�l!�...|
# |��)Z*���fKV��H4...|
# |        ��Xd]�j����|
# |�K޴Z�WQ��5f&�...|
# |       �4�ҙ*�Q�V%9W|
# |    �H�:��/mC��D;d|
# +--------------------+
