# %% [markdown]
# https://youtu.be/su3FGEa9t2g?si=pnFLpPxDrxbYa_Ou

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType
from pyspark.sql.functions import col, sum
from pyspark.sql.window import Window
data = [
(1, "A", 1000),
(2, "B", 2000),
(3, "C", 3000),
(4, "D", 4000),
]

schema1 = StructType([
  StructField("ID", IntegerType(), True),
  StructField("Name", StringType(), True),
  StructField("Sal", IntegerType(), True)
])
df2 = spark.createDataFrame(data, schema=schema1)
df2.show()
# Out:
# +---+----+----+
# | ID|Name| Sal|
# +---+----+----+
# |  1|   A|1000|
# |  2|   B|2000|
# |  3|   C|3000|
# |  4|   D|4000|
# +---+----+----+

# %%
df2.withColumn("Total_sum", sum(col("Sal")).over(Window.orderBy(col("ID")))).select("Total_sum").display()
# Out:
# /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/expressions.py:1160: UserWarning: WARN WindowExpression: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#   warnings.warn(
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Total_sum</th></tr></thead><tbody><tr><td>1000</td></tr><tr><td>3000</td></tr><tr><td>6000</td></tr><tr><td>10000</td></tr></tbody></table></div>
